# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import pyreadstat

# %%
raw = pd.read_csv('D:/song/python_practice/data/welfare/welfare.csv',
                  index_col = 0)
raw.head()
# Out:
#    h17_id    pid  inhouse_num  relation  sex   birth  edu  edu_detail  \
# 0     2.0  201.0          1.0      10.0  2.0  1945.0  4.0         5.0
# 1     3.0  301.0          1.0      10.0  1.0  1948.0  3.0         5.0
# 2     4.0  401.0          1.0      10.0  1.0  1942.0  7.0         3.0
# 3     6.0  601.0          1.0      10.0  1.0  1962.0  6.0         5.0
# 4     8.0  801.0          1.0      10.0  2.0  1940.0  3.0         3.0
#
#    disable_type  disable_degree  ...  live_together  industry    job  \
# 0           0.0             0.0  ...            1.0       NaN    NaN
# 1           0.0             0.0  ...            1.0      75.0  942.0
# 2           0.0             0.0  ...            1.0      42.0  762.0
# 3           0.0             0.0  ...            1.0      47.0  855.0
# 4           1.0             2.0  ...            1.0      84.0  941.0
#
#    inc_regular  inc_temp  inc_owner  sex_factor  marriage2 religion_factor  \
# ...

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16256 entries, 0 to 16255
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   h17_id           16256 non-null  float64
#  1   pid              16256 non-null  float64
#  2   inhouse_num      16256 non-null  float64
#  3   relation         16256 non-null  float64
#  4   sex              16256 non-null  float64
#  5   birth            16256 non-null  float64
#  6   edu              16256 non-null  float64
#  7   edu_detail       16256 non-null  float64
#  8   disable_type     16256 non-null  float64
#  9   disable_degree   16256 non-null  float64
#  10  marriage         16256 non-null  float64
#  11  religion         16256 non-null  int64
#  12  live_together    16256 non-null  float64
#  13  industry         8372 non-null   float64
#  14  job              8372 non-null   float64
#  15  inc_regular      2928 non-null   float64
# ...
