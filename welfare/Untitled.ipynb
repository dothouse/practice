# %% [markdown]
# # 복지패널 연습

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import pyreadstat

# %%
df, meta = pyreadstat.read_sav('d:/song/python_practice/data/welfare/Koweps_p17_2022_beta1.sav')
df.head()
# Out:
#    h17_id  h17_ind  h17_sn  h17_merkey  h_new  h_new1  h17_pind  h17_pid  \
# 0     2.0      1.0     1.0     20101.0    0.0     0.0       1.0    201.0
# 1     3.0      1.0     1.0     30101.0    0.0     0.0       1.0    301.0
# 2     4.0      1.0     1.0     40101.0    0.0     0.0       1.0    401.0
# 3     6.0      1.0     1.0     60101.0    0.0     0.0       1.0    601.0
# 4     6.0      1.0     1.0     60101.0    0.0     0.0       1.0    602.0
#
#    p17_fnum  p17_tq  ...  np1706_36  np1706_37  np1706_38  np1706_39  \
# 0       1.0     3.0  ...        NaN        NaN        NaN        NaN
# 1       1.0     3.0  ...        NaN        NaN        NaN        NaN
# 2       1.0     3.0  ...        NaN        NaN        NaN        NaN
# 3       1.0     3.0  ...        NaN        NaN        NaN        NaN
# 4       2.0     3.0  ...        NaN        NaN        NaN        NaN
#
#    np1706_40  np1706_41  np1706_42  np1706_43  np1706_44  p1706_3aq1
# ...

# %%
meta

# %%
df.h10_g3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.h10_g3
#
# File C:\Python39\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'h10_g3'
