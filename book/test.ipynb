# %%
import pandas as pd

# %%
raw = pd.read_csv('D:/song/dataset/요약문 및 레포트 생성 데이터/summary.csv')
raw.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_8872\1992184508.py:1: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv('D:/song/dataset/요약문 및 레포트 생성 데이터/summary.csv')
#                 doc_id doc_category doc_type  \
# 0  REPORT-news_r-00001       REPORT   news_r
# 1  REPORT-news_r-00005       REPORT   news_r
# 2  REPORT-news_r-00005       REPORT   news_r
# 3  REPORT-news_r-00009       REPORT   news_r
# 4  REPORT-news_r-00012       REPORT   news_r
#
#                               doc_name author publisher  publisher_year  \
# 0  40억달러 딜 주인공 김봉진 "국내서 폼잡다 죽고싶지 않았다"     김선영      중앙일보          2020.0
# 1         [차이나인사이트] 한한령 풀리면 한·중관계 회복될까    김선영      중앙일보          2020.0
# 2         [차이나인사이트] 한한령 풀리면 한·중관계 회복될까    김선영      중앙일보          2020.0
# 3           [이철호 칼럼] 문 대통령, 총알을 물어야 한다    김선영      중앙일보          2020.0
# 4     '北핵무력 강화 핵심' 이병철, 노동당 정치국 위원에 선출    정용수      중앙일보          2020.0
#
# ...

# %%
raw['doc_type'].unique()
# Out:
# array(['news_r', 'briefing', 'his_cul', 'paper', 'minute', 'edit',
#        'public', 'speech', 'literature', 'narration'], dtype=object)

# %%
df = raw[raw['doc_type'] == 'literature']
df.head()
# Out:
#                         doc_id doc_category    doc_type doc_name author  \
# 64400  REPORT-literature-07200       REPORT  literature   천재(天災)    윤기정
# 64401  REPORT-literature-07201       REPORT  literature      해돋이    최서해
# 64402  REPORT-literature-07202       REPORT  literature  수평선 너머로    김동인
# 64403  REPORT-literature-07203       REPORT  literature  아시아의 운명    채만식
# 64404  REPORT-literature-07204       REPORT  literature      광공자    김동인
#
#       publisher  publisher_year doc_origin                     passage_id  \
# 64400       NaN             NaN     저작권위원회  REPORT-literature-07200-07200
# 64401       NaN             NaN     저작권위원회  REPORT-literature-07201-07201
# 64402       NaN             NaN     저작권위원회  REPORT-literature-07202-07202
# 64403       NaN             NaN     저작권위원회  REPORT-literature-07203-07203
# 64404       NaN             NaN     저작권위원회  REPORT-literature-07204-07204
#
#                                                  passage  passage_Cnt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 64400 to 142630
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   doc_id          9600 non-null   object
#  1   doc_category    9600 non-null   object
#  2   doc_type        9600 non-null   object
#  3   doc_name        9600 non-null   object
#  4   author          9600 non-null   object
#  5   publisher       0 non-null      object
#  6   publisher_year  0 non-null      float64
#  7   doc_origin      9600 non-null   object
#  8   passage_id      9600 non-null   object
#  9   passage         9600 non-null   object
#  10  passage_Cnt     9600 non-null   int64
#  11  summary1        9600 non-null   object
#  12  summary2        4800 non-null   object
#  13  summary3        4800 non-null   object
#  14  summary_3_cnt   4800 non-null   float64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 1.2+ MB

# %%
for i in range(1):
    print(df['passage'][i])
    print('----------------')
    print(df['summary1'][i])
    print('----------------')
    print(df['summary2'][i])
    print('----------------')
    print(df['summary3'][i])
    print('----------------')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tjoeun\miniconda3\envs\chatbot\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 for i in range(1):
# ----> 2     print(df['passage'][i])
# ...
