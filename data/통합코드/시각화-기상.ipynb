# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import re

plt.rc('font',family='Malgun Gothic')

# %%
weather = pd.read_csv('weather_data/기상.csv',encoding='cp949')
weather
# Out:
#       지점  지점명       일시  평균기온(°C)  평균현지기압(hPa)  평균상대습도(%)  월합강수량(00~24h만)(mm)  \
# 0    184   제주  2015-01       7.4       1022.0         66                82.4
# 1    184   제주  2015-02       7.3       1020.2         64                35.5
# 2    184   제주  2015-03      10.4       1019.4         64                80.7
# 3    184   제주  2015-04      15.1       1013.5         71               147.9
# 4    184   제주  2015-05      18.8       1008.4         68               150.0
# ..   ...  ...      ...       ...          ...        ...                 ...
# 427  189  서귀포  2023-08      28.0        999.5         78               218.9
# 428  189  서귀포  2023-09      25.8       1006.4         75               126.4
# 429  189  서귀포  2023-10      19.9       1012.5         59                 5.9
# 430  189  서귀포  2023-11      14.5       1015.5         66                45.2
# 431  189  서귀포  2023-12       9.9       1017.8         69                74.7
#
#      평균풍속(m/s)  합계 일조시간(hr)  최심적설(cm)  평균지면온도(°C)
# 0          3.9         94.2       1.8         6.2
# 1          3.7         93.5       0.5         7.5
# 2          2.9        183.8       0.0        12.4
# 3          2.9        163.4       NaN        17.1
# 4          2.6        239.7       NaN        23.4
# ..         ...          ...       ...         ...
# 427        1.9        250.9       NaN        32.3
# 428        1.7        217.7       NaN        28.5
# 429        1.7        252.3       NaN        21.9
# 430        1.6        198.4       NaN        14.2
# 431        1.6        133.8       5.7         9.7
#
# [432 rows x 11 columns]

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   지점                  432 non-null    int64
#  1   지점명                 432 non-null    object
#  2   일시                  432 non-null    object
#  3   평균기온(°C)            432 non-null    float64
#  4   평균현지기압(hPa)         432 non-null    float64
#  5   평균상대습도(%)           432 non-null    int64
#  6   월합강수량(00~24h만)(mm)  432 non-null    float64
#  7   평균풍속(m/s)           431 non-null    float64
#  8   합계 일조시간(hr)         432 non-null    float64
#  9   최심적설(cm)            29 non-null     float64
#  10  평균지면온도(°C)          431 non-null    float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 37.2+ KB

# %%
weather["일시"] = pd.to_datetime(weather["일시"])
weather['연도']=weather['일시'].dt.year
weather['월']=weather['일시'].dt.month

# %%
weather['최심적설(cm)']=weather['최심적설(cm)'].fillna(0)

# %%
weather.describe()
# Out:
#                지점                   일시    평균기온(°C)  평균현지기압(hPa)   평균상대습도(%)  \
# count  432.000000                  432  432.000000   432.000000  432.000000
# mean   186.500000  2019-06-16 19:06:40   16.601389  1011.495370   74.245370
# min    184.000000  2015-01-01 00:00:00    4.000000   996.800000   55.000000
# 25%    184.750000  2017-03-24 06:00:00    9.875000  1005.750000   67.000000
# 50%    186.500000  2019-06-16 00:00:00   16.500000  1011.500000   72.500000
# 75%    188.250000  2021-09-08 12:00:00   22.525000  1016.950000   81.000000
# max    189.000000  2023-12-01 00:00:00   29.400000  1024.100000   97.000000
# std      2.063943                  NaN    7.081530     6.959977    9.273117
#
#        월합강수량(00~24h만)(mm)   평균풍속(m/s)  합계 일조시간(hr)    최심적설(cm)  평균지면온도(°C)  \
# count          432.000000  431.000000   432.000000  432.000000  431.000000
# mean           145.845602    3.560789   174.603935    0.258796   18.219954
# min              2.800000    1.400000    31.400000    0.000000    3.300000
# 25%             54.375000    2.300000   142.725000    0.000000   11.050000
# 50%            104.250000    3.000000   176.600000    0.000000   18.600000
# 75%            205.200000    4.000000   208.725000    0.000000   25.200000
# max            692.400000   10.000000   297.600000   14.400000   33.800000
# std            122.805590    1.917743    49.458923    1.399359    8.373925
#
#                 연도           월
# count   432.000000  432.000000
# mean   2019.000000    6.500000
# min    2015.000000    1.000000
# 25%    2017.000000    3.750000
# 50%    2019.000000    6.500000
# 75%    2021.000000    9.250000
# max    2023.000000   12.000000
# std       2.584983    3.456055

# %%
spot_ = '서귀포'
d_ = weather[(weather["지점명"]==spot_)]
plt.figure(figsize=(10,5))
plt.title("9월 %s 지점 기온 추이" % spot_, fontsize=15)
plt.plot(d_["일시"], d_["평균기온(°C)"], "-", color='orange', label=str(spot_))
plt.grid()
plt.legend(fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
weather.지점명.unique()
# Out:
# array(['제주', '고산', '성산', '서귀포'], dtype=object)

# %%
plt.figure(figsize=(10,5))
plt.title("1월 지점별 기온 추이", fontsize=15)
for spot_ in ['제주', '고산', '성산', '서귀포']:
    d_ = weather[(weather["지점명"]==spot_) & (weather["월"]==1)]
    plt.plot(d_["일시"], d_["평균기온(°C)"], "-", label=str(spot_), alpha=.6)
plt.grid()
plt.legend(fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
spot_ = '제주'
d_ = weather[(weather["지점명"]==spot_) & (weather["월"]==1)]
plt.figure(figsize=(10,5))
plt.title("1월 %s 지점 기온 추이" % spot_, fontsize=15)
plt.plot(d_["일시"], d_["평균기온(°C)"], "-", color='orange', label=str(spot_))
plt.axhline(y= d_["평균기온(°C)"].mean(), linestyle='--', color='red', label="mean")
#plt.axvline(x= pd.to_datetime("2019-01-01"), color='blue', label="spot")
plt.grid()
plt.legend(fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
weather.columns
# Out:
# Index(['지점', '지점명', '일시', '평균기온(°C)', '평균현지기압(hPa)', '평균상대습도(%)',
#        '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '합계 일조시간(hr)', '최심적설(cm)',
#        '평균지면온도(°C)', '연도', '월'],
#       dtype='object')

# %%
spot_ = '제주'
d_ = weather[(weather["지점명"]==spot_) & (weather["월"]==1)]
plt.figure(figsize=(10,5))
plt.title("1월 %s 지점 기온,풍속 추이" % spot_, fontsize=15)
plt.xticks(rotation=90)
ax1 = plt.subplot(111)
ax2 = ax1.twinx()
a, =  ax1.plot(d_["일시"], d_["평균기온(°C)"], "-", color='red', label="기온(°C)")
b, = ax2.plot(d_["일시"], d_["평균풍속(m/s)"], "-", color='blue', label="풍속(m/s)")
p = [a, b]
ax1.legend(p, [p_.get_label() for p_ in p])
plt.show()

# %%
ax = d_.plot('일시','평균기온(°C)', figsize=(10,5))
plt.title("1월 %s 지점 기온,풍속 추이" % spot_, fontsize=15)
d_.plot('일시','평균풍속(m/s)',secondary_y=True, ax=ax)
plt.show()

# %%
weather['지점명'].unique()
# Out:
# array(['제주', '고산', '성산', '서귀포'], dtype=object)

# %%
plt.figure(figsize=(10,8)) # 먼저 창을 만들고
n=1
for spot_ in ['제주', '고산', '성산', '서귀포']:
    d_ = weather[(weather["지점명"]==spot_) & (weather["월"]==12)]
    ax = plt.subplot(2,2,n) # for문을 돌면서 Axes를 추가
    plt.title("%s 지점 기온 추이" % spot_, fontsize=15)
    ax.plot(d_["일시"], d_["평균기온(°C)"], "-", label=str(spot_), alpha=.6) # 그래프 추가
    plt.xticks(rotation=90)
    n+=1
plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("9월 지점별 기온 추이", fontsize=15)
for spot_ in ['제주','고산','성산','서귀포']:
    d_ = weather[(weather["지점명"]==spot_) & (weather["월"]==9)]
    plt.plot(d_["일시"], d_["평균기온(°C)"], "-", label=str(spot_), alpha=.6)
plt.grid()
plt.legend(loc='upper left', fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
weather.columns
# Out:
# Index(['지점', '지점명', '일시', '평균기온(°C)', '평균현지기압(hPa)', '평균상대습도(%)',
#        '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '합계 일조시간(hr)', '최심적설(cm)',
#        '평균지면온도(°C)', '연도', '월'],
#       dtype='object')

# %%
heat_ = weather[['평균기온(°C)', '평균현지기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '합계 일조시간(hr)', '최심적설(cm)',
       '평균지면온도(°C)',]].dropna().copy()

# %%
import seaborn as sns
plt.figure(figsize=(8,8))
plt.title("Correlation", fontsize=15)
sns.heatmap(data = heat_.corr(),
            annot=True,
            fmt = '.2f', linewidths=.5, cmap='coolwarm',
           vmin = -1, vmax = 1, center = 0)
plt.show()
# Out:
# c:\Python39\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# c:\Python39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#!pip install folium
# !pip install charset
#!pip install pyproject-toml
# Out:
# Collecting charset
#   Using cached charset-1.0.1.tar.gz (189 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting chardet (from charset)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Building wheels for collected packages: charset
#   Building wheel for charset (setup.py): started
#   Building wheel for charset (setup.py): finished with status 'error'
#   Running setup.py clean for charset
# Failed to build charset
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-3.9
#       creating build\lib.win-amd64-3.9\charset
#       copying charset\cmd.py -> build\lib.win-amd64-3.9\charset
#       copying charset\__init__.py -> build\lib.win-amd64-3.9\charset
#       running egg_info
#       writing charset.egg-info\PKG-INFO
#       writing dependency_links to charset.egg-info\dependency_links.txt
#       writing entry points to charset.egg-info\entry_points.txt
#       writing requirements to charset.egg-info\requires.txt
#       writing top-level names to charset.egg-info\top_level.txt
#       reading manifest file 'charset.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.txt' under directory 'docs'
#       warning: no files found matching '*.txt' under directory 'languagedet\data'
#       warning: no files found matching '*.pickle' under directory 'languagedet\data'
#       warning: no files found matching '*.conf' under directory 'languagedet\data'
#       writing manifest file 'charset.egg-info\SOURCES.txt'
#       running build_ext
#       building 'charset.detector' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for charset
# ERROR: Could not build wheels for charset, which is required to install pyproject.toml-based projects

# %%
import folium
import pandas as pd

# %%
df = pd.read_excel('C:\workspace\project\지점정보.xlsx')

# %%
weather
# Out:
#       지점  지점명         일시  평균기온(°C)  평균현지기압(hPa)  평균상대습도(%)  \
# 0    184   제주 2015-01-01       7.4       1022.0         66
# 1    184   제주 2015-02-01       7.3       1020.2         64
# 2    184   제주 2015-03-01      10.4       1019.4         64
# 3    184   제주 2015-04-01      15.1       1013.5         71
# 4    184   제주 2015-05-01      18.8       1008.4         68
# ..   ...  ...        ...       ...          ...        ...
# 427  189  서귀포 2023-08-01      28.0        999.5         78
# 428  189  서귀포 2023-09-01      25.8       1006.4         75
# 429  189  서귀포 2023-10-01      19.9       1012.5         59
# 430  189  서귀포 2023-11-01      14.5       1015.5         66
# 431  189  서귀포 2023-12-01       9.9       1017.8         69
#
#      월합강수량(00~24h만)(mm)  평균풍속(m/s)  합계 일조시간(hr)  최심적설(cm)  평균지면온도(°C)    연도  \
# 0                  82.4        3.9         94.2       1.8         6.2  2015
# 1                  35.5        3.7         93.5       0.5         7.5  2015
# 2                  80.7        2.9        183.8       0.0        12.4  2015
# 3                 147.9        2.9        163.4       0.0        17.1  2015
# 4                 150.0        2.6        239.7       0.0        23.4  2015
# ..                  ...        ...          ...       ...         ...   ...
# 427               218.9        1.9        250.9       0.0        32.3  2023
# 428               126.4        1.7        217.7       0.0        28.5  2023
# 429                 5.9        1.7        252.3       0.0        21.9  2023
# 430                45.2        1.6        198.4       0.0        14.2  2023
# 431                74.7        1.6        133.8       5.7         9.7  2023
#
#       월
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5
# ..   ..
# 427   8
# 428   9
# 429  10
# 430  11
# 431  12
#
# [432 rows x 13 columns]

# %%
df_w = pd.merge(weather,df,on='지점',how = 'outer')
df_w = df_w.drop('지점명_y',axis=1)
df_w = df_w.rename(columns={'지점명_x':'지점명'})

# %%
df_w
# Out:
#       지점  지점명         일시  평균기온(°C)  평균현지기압(hPa)  평균상대습도(%)  \
# 0    184   제주 2015-01-01       7.4       1022.0         66
# 1    184   제주 2015-02-01       7.3       1020.2         64
# 2    184   제주 2015-03-01      10.4       1019.4         64
# 3    184   제주 2015-04-01      15.1       1013.5         71
# 4    184   제주 2015-05-01      18.8       1008.4         68
# ..   ...  ...        ...       ...          ...        ...
# 427  189  서귀포 2023-08-01      28.0        999.5         78
# 428  189  서귀포 2023-09-01      25.8       1006.4         75
# 429  189  서귀포 2023-10-01      19.9       1012.5         59
# 430  189  서귀포 2023-11-01      14.5       1015.5         66
# 431  189  서귀포 2023-12-01       9.9       1017.8         69
#
#      월합강수량(00~24h만)(mm)  평균풍속(m/s)  합계 일조시간(hr)  최심적설(cm)  평균지면온도(°C)    연도  \
# 0                  82.4        3.9         94.2       1.8         6.2  2015
# 1                  35.5        3.7         93.5       0.5         7.5  2015
# 2                  80.7        2.9        183.8       0.0        12.4  2015
# 3                 147.9        2.9        163.4       0.0        17.1  2015
# 4                 150.0        2.6        239.7       0.0        23.4  2015
# ..                  ...        ...          ...       ...         ...   ...
# 427               218.9        1.9        250.9       0.0        32.3  2023
# 428               126.4        1.7        217.7       0.0        28.5  2023
# 429                 5.9        1.7        252.3       0.0        21.9  2023
# 430                45.2        1.6        198.4       0.0        14.2  2023
# 431                74.7        1.6        133.8       5.7         9.7  2023
#
#       월                             지점주소       위도        경도
# 0     1     제주특별자치도 제주시만덕로 6길 32 제주지방기상청  33.5141  126.5297
# 1     2     제주특별자치도 제주시만덕로 6길 32 제주지방기상청  33.5141  126.5297
# 2     3     제주특별자치도 제주시만덕로 6길 32 제주지방기상청  33.5141  126.5297
# 3     4     제주특별자치도 제주시만덕로 6길 32 제주지방기상청  33.5141  126.5297
# 4     5     제주특별자치도 제주시만덕로 6길 32 제주지방기상청  33.5141  126.5297
# ..   ..                              ...      ...       ...
# 427   8  제주특별자치도 서귀포시태평로 439번길17 서귀포관측소   33.2462  126.5653
# 428   9  제주특별자치도 서귀포시태평로 439번길17 서귀포관측소   33.2462  126.5653
# 429  10  제주특별자치도 서귀포시태평로 439번길17 서귀포관측소   33.2462  126.5653
# 430  11  제주특별자치도 서귀포시태평로 439번길17 서귀포관측소   33.2462  126.5653
# 431  12  제주특별자치도 서귀포시태평로 439번길17 서귀포관측소   33.2462  126.5653
#
# [432 rows x 16 columns]

# %%
df_w =

# %%
map=folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)
map

# %%
#제주시(blue)-서귀포시(green) 구분해서 folium.Marker
tiles = "http://mt0.google.com/vt/lyrs=m&hl=ko&x={x}&y={y}&z={z}" #구글지도 타일 설정
attr= "Google" #속성 설정
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], #folium을 사용하여 지도 초기화
                 tiles=tiles, attr=attr)
for i in df.index: #df의 각 행을 반복
    folium.Marker(
        location=[df.loc[i, '위도'], df.loc[i, '경도']],
        tooltip=df.loc[i, '지점명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 약국명 표시
        popup=folium.Popup(df.loc[i, '지점주소'], max_width=200),
        icon=folium.Icon(color='darkred', icon='sun',prefix='fa')
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_762105ff0498a8b1065677ce316c38fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_762105ff0498a8b1065677ce316c38fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_762105ff0498a8b1065677ce316c38fd = L.map(
#                 &quot;map_762105ff0498a8b1065677ce316c38fd&quot;,
#                 {
#                     center: [33.360225, 126.5345],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d9996945eef48d5f0250a45232973f1 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=m\u0026hl=ko\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_1d9996945eef48d5f0250a45232973f1.addTo(map_762105ff0498a8b1065677ce316c38fd);
#
#             var marker_b1e06beffed549226794420ae958d949 = L.marker(
#                 [33.5141, 126.5297],
#                 {}
#             ).addTo(map_762105ff0498a8b1065677ce316c38fd);
#
#
#             var icon_4e2353ee045e27a051e2e56665430f38 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sun&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b1e06beffed549226794420ae958d949.setIcon(icon_4e2353ee045e27a051e2e56665430f38);
#
#
#         var popup_e560a38e5d9a4e929fe61c7bac88e127 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_e2b7ca01bf487453b389f74462c27ab1 = $(`&lt;div id=&quot;html_e2b7ca01bf487453b389f74462c27ab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시만덕로 6길 32 제주지방기상청&lt;/div&gt;`)[0];
#                 popup_e560a38e5d9a4e929fe61c7bac88e127.setContent(html_e2b7ca01bf487453b389f74462c27ab1);
#
#
#
#         marker_b1e06beffed549226794420ae958d949.bindPopup(popup_e560a38e5d9a4e929fe61c7bac88e127)
#         ;
#
#
#
#
#             marker_b1e06beffed549226794420ae958d949.bindTooltip(
#                 `&lt;div&gt;
#                      제주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_21f553573610eff02f1e4a3001cdba74 = L.marker(
#                 [33.2938, 126.1628],
#                 {}
#             ).addTo(map_762105ff0498a8b1065677ce316c38fd);
#
#
#             var icon_dc622538a6abdc786fa1452800df1e7a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sun&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_21f553573610eff02f1e4a3001cdba74.setIcon(icon_dc622538a6abdc786fa1452800df1e7a);
#
#
#         var popup_91a412e82d83920495a022fde96483bb = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_24f52ef85450d1241d71a378e1ce3f12 = $(`&lt;div id=&quot;html_24f52ef85450d1241d71a378e1ce3f12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시한경면 노을해안로1013-70 고산레이더관측소 &lt;/div&gt;`)[0];
#                 popup_91a412e82d83920495a022fde96483bb.setContent(html_24f52ef85450d1241d71a378e1ce3f12);
#
#
#
#         marker_21f553573610eff02f1e4a3001cdba74.bindPopup(popup_91a412e82d83920495a022fde96483bb)
#         ;
#
#
#
#
#             marker_21f553573610eff02f1e4a3001cdba74.bindTooltip(
#                 `&lt;div&gt;
#                      고산
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7261697b966fafea3be0651a218ecd77 = L.marker(
#                 [33.3868, 126.8802],
#                 {}
#             ).addTo(map_762105ff0498a8b1065677ce316c38fd);
#
#
#             var icon_ce7fe063f801b929b48d83634ffd70c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;sun&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7261697b966fafea3be0651a218ecd77.setIcon(icon_ce7fe063f801b929b48d83634ffd70c7);
#
#
#         var popup_80feac18096a1ba5eb923467ca10ce21 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_4d050c7c7fda7f59a319559f34d48124 = $(`&lt;div id=&quot;html_4d050c7c7fda7f59a319559f34d48124&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 서귀포시성산읍 신난로11 성산레이더관측소 &lt;/div&gt;`)[0];
#                 popup_80feac18096a1ba5eb923467ca10ce21.setContent(html_4d050c7c7fda7f59a319559f34d48124);
#
#
#
#         marker_7261697b966fafea3be0651a218ecd77.bindPopup(popup_80feac18096a1ba5eb923467ca10ce21)
#         ;
#
#
#
#
#             marker_7261697b966fafea3be0651a218ecd77.bindTooltip(
#                 `&lt;div&gt;
