# %%
import pandas as pd

# %%
df_base = pd.read_csv('./test_data/distance_test.csv')
df_base.head(3)
# Out:
#       ID         이름                         주소      주소2         위도  \
# 0  10001   중문삼성연합의원         제주특별자치도 서귀포시 중문로 7      중문동  33.252693
# 1  10002  조재익신경외과의원  제주특별자치도 서귀포시 대정읍 하모중앙로 76  대정읍 하모리  33.221390
# 2  10003   제주현대안과의원         제주특별자치도 제주시 건주로 31     도련일동  33.516779
#
#            경도   구분  토요일  일요일  공휴일  ...  pension82  pension83  pension84  \
# 0  126.423028   의원  1.0  0.0  0.0  ...  23.814395  24.961455  25.343184
# 1  126.251812   의원  1.0  0.0  0.0  ...  24.585386  28.313086  29.581745
# 2  126.580983   의원  0.0  1.0  0.0  ...  27.707602  23.243140  21.568000
#
#    pension85  pension86  pension87  pension88  pension89  pension90  pension91
# 0  39.174576  23.107134  49.471771  49.105315  47.472579  19.813939  24.501387
# 1  55.474208  19.791686  64.297131  65.131295  63.598842  28.793695  26.049520
# 2  31.843835  33.639742  23.134769  31.411171  31.588453  16.632509  26.366539
#
# [3 rows x 104 columns]

# %%
df_base.columns[1:13]
# Out:
# Index(['이름', '주소', '주소2', '위도', '경도', '구분', '토요일', '일요일', '공휴일', '홈페이지',
#        '비고(m)', '표고(m)'],
#       dtype='object')

# %%
df_base.drop(columns=df_base.columns[1:13], inplace= True)
df_base
# Out:
#          ID   pension1   pension2   pension3   pension4   pension5   pension6  \
# 0     10001  40.818829  25.288613  26.622110  18.393758   9.141501  29.543271
# 1     10002  55.625875  30.919499  36.594309  23.501626  25.361900  43.856997
# 2     10003  16.144699  19.002091   9.478529  23.304015  29.443596   9.172378
# 3     10004  17.200939  18.081753   8.652134  22.584225  29.560514  10.021634
# 4     10005  20.896363  13.803612   4.222092  18.147043  27.080137  11.641078
# ...     ...        ...        ...        ...        ...        ...        ...
# 2323  60085  14.699669  19.829544  10.144194  23.193632  27.005895   6.183138
# 2324  60086  25.646660  24.631936  19.910504  21.541133   8.583477  15.425677
# 2325  60087  10.587461  38.354707  29.300652  39.088664  29.486067  14.628307
# 2326  60088   9.940012  43.953650  34.359779  45.999497  38.916568  20.327839
# 2327  60089  14.187216  45.242250  36.028574  46.136859  35.635437  21.355728
#
#        pension7   pension8   pension9  ...  pension82  pension83  pension84  \
# 0     25.549011  25.246800  25.408769  ...  23.814395  24.961455  25.343184
# 1     27.458217  31.407341  34.692064  ...  24.585386  28.313086  29.581745
# 2     25.608978  18.007564  11.733968  ...  27.707602  23.243140  21.568000
# 3     24.688183  17.092032  10.905147  ...  26.833474  22.329553  20.643460
# 4     20.402941  12.803200   6.477768  ...  22.456875  18.028922  16.372397
# ...         ...        ...        ...  ...        ...        ...        ...
# 2323  26.370814  18.824478  12.303100  ...  28.217037  23.987043  22.386612
# 2324  28.641906  23.995121  20.091781  ...  28.544393  26.859574  26.190349
# 2325  44.377942  37.397216  31.057751  ...  45.488447  42.083100  40.736668
# 2326  50.358563  42.955118  36.411728  ...  51.886863  47.988880  46.471944
# 2327  51.342983  44.273973  37.866423  ...  52.505981  49.032822  47.655290
#
#       pension85  pension86  pension87  pension88  pension89  pension90  \
# 0     39.174576  23.107134  49.471771  49.105315  47.472579  19.813939
# 1     55.474208  19.791686  64.297131  65.131295  63.598842  28.793695
# 2     31.843835  33.639742  23.134769  31.411171  31.588453  16.632509
# 3     32.805381  32.817748  24.119304  32.476119  32.648754  15.987873
# 4     34.584017  28.387826  28.268534  35.730322  35.660342  11.621854
# ...         ...        ...        ...        ...        ...        ...
# 2323  29.060212  33.872849  22.391649  29.475496  29.456019  16.348494
# 2324  24.625230  31.273492  34.174347  33.462623  31.938314  17.487730
# 2325   9.940304  49.996237  15.791461  11.602556  10.427811  32.711830
# 2326  16.029614  56.978823   8.483123   5.934049   7.385559  39.271641
# 2327   9.224037  57.048920  15.434303   5.199233   3.421286  39.728578
#
#       pension91
# 0     24.501387
# 1     26.049520
# 2     26.366539
# 3     25.471637
# 4     21.129741
# ...         ...
# 2323  26.988218
# 2324  28.292097
# 2325  44.622348
# 2326  50.819377
# 2327  51.616751
#
# [2328 rows x 92 columns]

# %%
df_base['type'] = df_base['ID'].apply(lambda x: x // 10000)
df_base.head(5)
# Out:
#       ID   pension1   pension2   pension3   pension4   pension5   pension6  \
# 0  10001  40.818829  25.288613  26.622110  18.393758   9.141501  29.543271
# 1  10002  55.625875  30.919499  36.594309  23.501626  25.361900  43.856997
# 2  10003  16.144699  19.002091   9.478529  23.304015  29.443596   9.172378
# 3  10004  17.200939  18.081753   8.652134  22.584225  29.560514  10.021634
# 4  10005  20.896363  13.803612   4.222092  18.147043  27.080137  11.641078
#
#     pension7   pension8   pension9  ...  pension83  pension84  pension85  \
# 0  25.549011  25.246800  25.408769  ...  24.961455  25.343184  39.174576
# 1  27.458217  31.407341  34.692064  ...  28.313086  29.581745  55.474208
# 2  25.608978  18.007564  11.733968  ...  23.243140  21.568000  31.843835
# 3  24.688183  17.092032  10.905147  ...  22.329553  20.643460  32.805381
# 4  20.402941  12.803200   6.477768  ...  18.028922  16.372397  34.584017
#
#    pension86  pension87  pension88  pension89  pension90  pension91  type
# 0  23.107134  49.471771  49.105315  47.472579  19.813939  24.501387     1
# 1  19.791686  64.297131  65.131295  63.598842  28.793695  26.049520     1
# 2  33.639742  23.134769  31.411171  31.588453  16.632509  26.366539     1
# 3  32.817748  24.119304  32.476119  32.648754  15.987873  25.471637     1
# 4  28.387826  28.268534  35.730322  35.660342  11.621854  21.129741     1
#
# [5 rows x 93 columns]

# %%
result = []
for i in df_base.columns[1:-2]:
    for spot_type in range(1, 7):
        temp = df_base[df_base['type'] == spot_type]
        cnt1 = ((temp[f'{i}'] < 1).sum())
        cnt2 = ((temp[f'{i}'] < 2).sum())
        cnt3 = ((temp[f'{i}'] < 3).sum())
        cnt5 = ((temp[f'{i}'] < 5).sum())
        cnt10 = ((temp[f'{i}'] < 10).sum())
        cnt15 = ((temp[f'{i}'] < 15).sum())
        cnt20 = ((temp[f'{i}'] < 20).sum())
        result.append([i, spot_type, cnt1, cnt2, cnt3, cnt5, cnt10, cnt15, cnt20])

# %%
df_result = pd.DataFrame(result)
df_result.columns = ['name', 'type', 'cnt_1km','cnt_2km', 'cnt_3km','cnt_5km', 'cnt_10km', 'cnt_15km', 'cnt_20km']

# %%
df_result
# Out:
#           name  type  cnt_1km  cnt_2km  cnt_3km  cnt_5km  cnt_10km  cnt_15km  \
# 0     pension1     1        0        1        1        3        20        52
# 1     pension1     2        0        0        0        0         7        17
# 2     pension1     3        0        0        0        1        21        32
# 3     pension1     4        0        0        0        1        13        23
# 4     pension1     5        0        0        0        1         3         5
# ..         ...   ...      ...      ...      ...      ...       ...       ...
# 535  pension90     2        0        0        0        0        86       182
# 536  pension90     3        0        1        2        7        90       194
# 537  pension90     4        0        2        2        6       131       322
# 538  pension90     5        0        0        0        0         6        16
# 539  pension90     6        0        0        1        1         2        12
#
#      cnt_20km
# 0         239
# 1          78
# 2          95
# 3         103
# 4          13
# ..        ...
# 535       222
# 536       232
# 537       366
# 538        22
# 539        23
#
# [540 rows x 9 columns]

# %%
test1 = df_result[df_result['type'] == 1]
test2 = df_result[df_result['type'] == 2]
test3 = df_result[df_result['type'] == 3]
test4 = df_result[df_result['type'] == 4]
test5 = df_result[df_result['type'] == 5]
test6 = df_result[df_result['type'] == 6]

# %%
def cal_outlier(x, type_num, kilo):
    temp = x[x['type'] == type_num][f'cnt_{kilo}km']

    IQR = temp.quantile(0.75) - temp.quantile(0.25)
    Q3 = temp.quantile(0.75)
    Q1 = temp.quantile(0.25)

    globals()['df_type' + str(type_num)] = pd.DataFrame(temp[(temp > (Q3 + (1.5 * IQR))) | (temp < (Q1 - (1.5 * IQR)))])
    globals()['df_type' + str(type_num)].columns = [f'type{type_num}_3km']

# %%
df_temp = pd.DataFrame()

for type_num in range(1, 7):
    cal_outlier(df_result, type_num, 3)
    df_temp = globals()['df_type' + str(type_num)]
    globals()['df_type' + str(type_num)] = df_temp.merge(df_result, how = 'left', left_index=True, right_index=True)

# %%
test = pd.concat([df_type1, df_type2, df_type3, df_type4, df_type5, df_type6])
test
# Out:
#      type1_3km       name  type  cnt_1km  cnt_2km  cnt_3km  cnt_5km  cnt_10km  \
# 12       242.0   pension3     1      203      233      242      430       629
# 48       226.0   pension9     1        2      151      226      272       579
# 90       218.0  pension16     1        0       58      218      268       579
# 144      112.0  pension25     1        0        9      112      117       143
# 408      286.0  pension69     1       42      228      286      529       636
# 13         NaN   pension3     2       57       70       74      125       195
# 49         NaN   pension9     2        2       37       68       85       177
# 91         NaN  pension16     2        0       19       66       83       177
# 145        NaN  pension25     2        0        3       31       33        40
# 409        NaN  pension69     2       25       64       86      153       199
# 14         NaN   pension3     3       32       55       65      135       195
# 50         NaN   pension9     3        2       24       59       83       187
# 92         NaN  pension16     3        1       12       50       78       187
# 146        NaN  pension25     3        1        8       32       39        54
# 410        NaN  pension69     3       19       51       74      153       199
# 15         NaN   pension3     4       65       90      108      232       325
# 27         NaN   pension5     4        8       18       20       62        76
# 51         NaN   pension9     4        3       34       80      126       310
# 93         NaN  pension16     4        2       16       74      122       311
# 147        NaN  pension25     4        1        6       37       47        66
# 201        NaN  pension34     4        9       20       20       54        77
# 411        NaN  pension69     4       39       94      141      271       326
# 16         NaN   pension3     5        0        2        3        7        15
# 28         NaN   pension5     5        1        3        3        5         8
# 52         NaN   pension9     5        1        1        3        4        15
# 202        NaN  pension34     5        1        3        3        5         8
# 412        NaN  pension69     5        1        1        4        9        16
# 514        NaN  pension86     5        0        1        3        3         6
# 101        NaN  pension17     6        0        0        9       13        35
#
#      cnt_15km  cnt_20km  type2_3km  type3_3km  type4_3km  type5_3km  type6_3km
# 12        647       672        NaN        NaN        NaN        NaN        NaN
# 48        647       692        NaN        NaN        NaN        NaN        NaN
# 90        647       693        NaN        NaN        NaN        NaN        NaN
# 144       171       178        NaN        NaN        NaN        NaN        NaN
# 408       654       673        NaN        NaN        NaN        NaN        NaN
# 13        202       212       74.0        NaN        NaN        NaN        NaN
# 49        204       219       68.0        NaN        NaN        NaN        NaN
# 91        204       218       66.0        NaN        NaN        NaN        NaN
# 145        52        52       31.0        NaN        NaN        NaN        NaN
# 409       203       212       86.0        NaN        NaN        NaN        NaN
# 14        208       227        NaN       65.0        NaN        NaN        NaN
# 50        209       228        NaN       59.0        NaN        NaN        NaN
# 92        209       228        NaN       50.0        NaN        NaN        NaN
# 146        67        71        NaN       32.0        NaN        NaN        NaN
# 410       211       228        NaN       74.0        NaN        NaN        NaN
# 15        338       353        NaN        NaN      108.0        NaN        NaN
# 27         84        97        NaN        NaN       20.0        NaN        NaN
# 51        337       351        NaN        NaN       80.0        NaN        NaN
# 93        337       353        NaN        NaN       74.0        NaN        NaN
# 147        85        97        NaN        NaN       37.0        NaN        NaN
# 201        84        97        NaN        NaN       20.0        NaN        NaN
# 411       341       354        NaN        NaN      141.0        NaN        NaN
# 16         16        19        NaN        NaN        NaN        3.0        NaN
# 28          9        11        NaN        NaN        NaN        3.0        NaN
# 52         17        19        NaN        NaN        NaN        3.0        NaN
# 202         9        11        NaN        NaN        NaN        3.0        NaN
# 412        17        19        NaN        NaN        NaN        4.0        NaN
# 514         8        13        NaN        NaN        NaN        3.0        NaN
# 101        49        55        NaN        NaN        NaN        NaN        9.0

# %%
test2 = pd.concat([df_type1, df_type2, df_type3, df_type4])
test2
# Out:
#      type1_3km       name  type  cnt_1km  cnt_2km  cnt_3km  cnt_5km  cnt_10km  \
# 12       242.0   pension3     1      203      233      242      430       629
# 48       226.0   pension9     1        2      151      226      272       579
# 90       218.0  pension16     1        0       58      218      268       579
# 144      112.0  pension25     1        0        9      112      117       143
# 408      286.0  pension69     1       42      228      286      529       636
# 13         NaN   pension3     2       57       70       74      125       195
# 49         NaN   pension9     2        2       37       68       85       177
# 91         NaN  pension16     2        0       19       66       83       177
# 145        NaN  pension25     2        0        3       31       33        40
# 409        NaN  pension69     2       25       64       86      153       199
# 14         NaN   pension3     3       32       55       65      135       195
# 50         NaN   pension9     3        2       24       59       83       187
# 92         NaN  pension16     3        1       12       50       78       187
# 146        NaN  pension25     3        1        8       32       39        54
# 410        NaN  pension69     3       19       51       74      153       199
# 15         NaN   pension3     4       65       90      108      232       325
# 27         NaN   pension5     4        8       18       20       62        76
# 51         NaN   pension9     4        3       34       80      126       310
# 93         NaN  pension16     4        2       16       74      122       311
# 147        NaN  pension25     4        1        6       37       47        66
# 201        NaN  pension34     4        9       20       20       54        77
# 411        NaN  pension69     4       39       94      141      271       326
#
#      cnt_15km  cnt_20km  type2_3km  type3_3km  type4_3km
# 12        647       672        NaN        NaN        NaN
# 48        647       692        NaN        NaN        NaN
# 90        647       693        NaN        NaN        NaN
# 144       171       178        NaN        NaN        NaN
# 408       654       673        NaN        NaN        NaN
# 13        202       212       74.0        NaN        NaN
# 49        204       219       68.0        NaN        NaN
# 91        204       218       66.0        NaN        NaN
# 145        52        52       31.0        NaN        NaN
# 409       203       212       86.0        NaN        NaN
# 14        208       227        NaN       65.0        NaN
# 50        209       228        NaN       59.0        NaN
# 92        209       228        NaN       50.0        NaN
# 146        67        71        NaN       32.0        NaN
# 410       211       228        NaN       74.0        NaN
# 15        338       353        NaN        NaN      108.0
# 27         84        97        NaN        NaN       20.0
# 51        337       351        NaN        NaN       80.0
# 93        337       353        NaN        NaN       74.0
# 147        85        97        NaN        NaN       37.0
# 201        84        97        NaN        NaN       20.0
# 411       341       354        NaN        NaN      141.0

# %%
out_list = test2['name'].unique()
out_list
# Out:
# array(['pension3', 'pension9', 'pension16', 'pension25', 'pension69',
#        'pension5', 'pension34'], dtype=object)

# %%
df_result2 = df_result
for out_pension in out_list:
    df_result2 = df_result2[df_result2['name'] != out_pension]

# %%
df_result2['name'].nunique()
# Out:
# 83

# %%
df_result['name'].nunique()
# Out:
# 90

# %%
df = df_result2
df.reset_index(inplace=True)
df.rename(columns={'index' : 'id'})
# Out:
#       id       name  type  cnt_1km  cnt_2km  cnt_3km  cnt_5km  cnt_10km  \
# 0      0   pension1     1        0        1        1        3        20
# 1      1   pension1     2        0        0        0        0         7
# 2      2   pension1     3        0        0        0        1        21
# 3      3   pension1     4        0        0        0        1        13
# 4      4   pension1     5        0        0        0        1         3
# ..   ...        ...   ...      ...      ...      ...      ...       ...
# 493  535  pension90     2        0        0        0        0        86
# 494  536  pension90     3        0        1        2        7        90
# 495  537  pension90     4        0        2        2        6       131
# 496  538  pension90     5        0        0        0        0         6
# 497  539  pension90     6        0        0        1        1         2
#
#      cnt_15km  cnt_20km
# 0          52       239
# 1          17        78
# 2          32        95
# 3          23       103
# 4           5        13
# ..        ...       ...
# 493       182       222
# 494       194       232
# 495       322       366
# 496        16        22
# 497        12        23
#
# [498 rows x 10 columns]

# %%
df.to_csv('./test_data/test.csv', index= False)

# %%
test = df.sort_values('cnt_1km',ascending=False)
test
# Out:
#      index       name  type  cnt_1km  cnt_2km  cnt_3km  cnt_5km  cnt_10km  \
# 204    240  pension41     1       28       30       31       31        47
# 426    468  pension79     1       24       27       27       29        51
# 252    288  pension49     1       14       15       15       16        51
# 462    504  pension85     1       13       13       13       15        22
# 205    241  pension41     2       11       11       11       11        16
# ..     ...        ...   ...      ...      ...      ...      ...       ...
# 165    195  pension33     4        0        2        6        7        12
# 164    194  pension33     3        0        2        9       10        17
# 163    193  pension33     2        0        4       11       11        16
# 162    192  pension33     1        0        4       30       31        47
# 497    539  pension90     6        0        0        1        1         2
#
#      cnt_15km  cnt_20km
# 204        67       120
# 426        67        86
# 252       177       215
# 462        37        57
# 205        20        37
# ..        ...       ...
# 165        34        61
# 164        30        65
# 163        20        47
# 162        72       146
# 497        12        23
#
# [498 rows x 10 columns]

# %%
temp = test[test['cnt_1km'] == test['cnt_1km']]['cnt_1km'].sort_values(ascending=False)
temp.values[0]
# Out:
# 28

# %%
result_mean = []
for spot_type in range(1, 7):
    test = df_result2[df_result2['type'] == spot_type]
    mean_1km = test['cnt_1km'].mean()
    mean_3km = test['cnt_3km'].mean()
    mean_5km = test['cnt_5km'].mean()
    mean_10km = test['cnt_10km'].mean()
    result_mean.append([spot_type, mean_1km, mean_3km, mean_5km, mean_10km])

result_mean = pd.DataFrame(result_mean)
result_mean.columns = ['type', 'mean_1km','mean_3km', 'mean_5km', 'mean_10km']
result_mean
# Out:
#    type  mean_1km  mean_3km   mean_5km   mean_10km
# 0     1  1.650602  7.614458  20.855422  101.939759
# 1     2  0.638554  2.759036   7.120482   31.746988
# 2     3  1.000000  4.216867   9.265060   36.421687
# 3     4  0.746988  3.566265   8.951807   43.710843
# 4     5  0.108434  0.710843   1.542169    4.795181
# 5     6  0.084337  1.156627   3.253012   10.361446

# %%
df_sum = df.sum(axis=0)
df_sum = pd.DataFrame(df_sum)
df_sum.reset_index(inplace=True)

# %%
df_sum
# Out:
#       index                                                  0
# 0      name  pension1pension1pension1pension1pension1pensio...
# 1      type                                               1743
# 2   cnt_1km                                                351
# 3   cnt_2km                                                946
# 4   cnt_3km                                               1662
# 5   cnt_5km                                               4232
# 6  cnt_10km                                              19005
# 7  cnt_15km                                              46929
# 8  cnt_20km                                              72376

# %%
df_sum = df_sum.iloc[2: ]
df_sum.columns = ['name', 'score']

# %%
df_sum.reset_index(inplace=True)
df_sum
# Out:
#    index      name  score
# 0      2   cnt_1km    351
# 1      3   cnt_2km    946
# 2      4   cnt_3km   1662
# 3      5   cnt_5km   4232
# 4      6  cnt_10km  19005
# 5      7  cnt_15km  46929
# 6      8  cnt_20km  72376

# %%
df_sum.to_csv('./data/sum.csv', index=False)
